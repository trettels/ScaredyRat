# %% [markdown]
# # scaredyrat-ext analyzes data from extinction protocol

# %%
# notebook formatting and loading settings, imports - keep same

# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import math
import time
import os, sys

sys.path.append('../src')
import scaredyrattools as sr

# %% [markdown]
# # Change variables in this cell:

# %%
inpath = r'C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03'

outpath = r'C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\SR_OUT'

ntones = 3

#filelist = ['Raw data-PFC-PAG DREADDs July 2018-Trial     3.xlsx',
#            'Raw data-PFC-PAG DREADDs July 2018-Trial    10.xlsx',
#            'Raw data-PFC-PAG DREADDs July 2018-Trial    11.xlsx',
#            'Raw data-PFC-PAG DREADDs July 2018-Trial    12.xlsx',
#            'Raw data-PFC-PAG DREADDs July 2018-Trial    15.xlsx']

filelist = []
for entry in os.scandir(inpath):
    if entry.is_file():
        filelist.append(entry.path)

# %%
## don't need to change this - stays constant across file
sheetlist = ['Track-Arena 1-Subject 1', 'Track-Arena 2-Subject 1', 
             'Track-Arena 3-Subject 1', 'Track-Arena 4-Subject 1']

# %% [markdown]
# # Function calls below

# %%
for file in filelist:
    for sheet in sheetlist:

        ## set number of tones and input/output info
        ID,ctx,anim = sr.animal_read(inpath,file,sheet)
        if(ctx != "Ext. Retrieval" or ID == "-1" or ID=="nan" or (isinstance(ID,float) and math.isnan(float(ID)))):
            continue
        ## use scaredyrattools function to find where each epoch is
        tones = sr.find_tones(anim, ntones)
        pretones = sr.find_pretones(anim, ntones)
        shocks = sr.find_shock_responses(anim, ntones)
        pshocks = sr.find_postshocks(anim, ntones)

        ## use scaredyrattools function to find top n velocities
        mtone = sr.get_top_vels(tones,10,ntones)
        mptone = sr.get_top_vels(pretones,10,ntones)
        mshock = sr.get_top_vels(shocks,5,ntones)
        mpshock = sr.get_top_vels(pshocks,10,ntones)

        ## define names of CSV files to save to
        mToneOutfile = outpath + '/extRet-tone-max-vels-{}.csv' 
        mToneOutfile = mToneOutfile.format(ID)

        mPToneOutfile = outpath + '/extRet-pretone-max-vels-{}.csv' 
        mPToneOutfile = mPToneOutfile.format(ID)

        mShockOutfile = outpath + '/extRet-shock-max-vels-{}.csv' 
        mShockOutfile = mShockOutfile.format(ID)

        mPShockOutfile = outpath + '/extRet-postshock-max-vels-{}.csv' 
        mPShockOutfile = mPShockOutfile.format(ID)

        ## send files to previously defined CSVs
        mtone.to_csv(mToneOutfile)
        mptone.to_csv(mPToneOutfile)
        mshock.to_csv(mShockOutfile)
        mpshock.to_csv(mPShockOutfile)

        ## use scaredyrattools function to find means
        tmeans = sr.get_means(tones,'Tone',ntones)
        ptmeans = sr.get_means(pretones,'Pre-tone',ntones)
        smeans = sr.get_means(shocks,'Shock',ntones)
        pshockmeans = sr.get_means(pshocks,'Post-shock',ntones)
        allmeans = pd.concat([tmeans, ptmeans, smeans, pshockmeans],axis=1)

        ## use scaredyrattools function to find SEMs
        tSEMs = sr.get_SEMs(tones,'Tone',ntones)
        ptSEMs = sr.get_SEMs(pretones,'Pre-tone',ntones)
        sSEMs = sr.get_SEMs(shocks,'Shock',ntones)
        pshockSEMs = sr.get_SEMs(pshocks,'Post-shock',ntones)
        allSEMs = pd.concat([tSEMs, ptSEMs, sSEMs, pshockSEMs],axis=1)

        ## use scaredyrattools function to find medians
        tmeds = sr.get_meds(tones,'Tone',ntones)
        ptmeds = sr.get_meds(pretones,'Pre-tone',ntones)
        smeds = sr.get_meds(shocks,'Shock',ntones)
        pshockmeds = sr.get_meds(pshocks,'Post-shock',ntones)
        allmeds = pd.concat([tmeds, ptmeds, smeds, pshockmeds],axis=1)

        ## define names of CSV files to save to
        meanOutfile = outpath + '/extRet-mean-{}.csv' 
        meanOutfile = meanOutfile.format(ID)

        SEMOutfile = outpath + '/extRet-SEM-{}.csv' 
        SEMOutfile = SEMOutfile.format(ID)

        medOutfile = outpath + '/extRet-med-{}.csv' 
        medOutfile = medOutfile.format(ID)

        allmeans.to_csv(meanOutfile)
        allSEMs.to_csv(SEMOutfile)
        allmeds.to_csv(medOutfile)
        
        ## sr tools to find freezing
        toneFreezing, FTs = sr.get_freezing(tones,ntones,freezingThreshold=0.1, binSecs=1)
        ptFreezing, ptFTs = sr.get_freezing(pretones,ntones,freezingThreshold=0.1, binSecs=1)
        shockFreezing, shockFTs = sr.get_freezing(shocks,ntones,freezingThreshold=0.1, binSecs=1)
        pshockFreezing, pshockFTs = sr.get_freezing(pshocks,ntones,freezingThreshold=0.1, binSecs=1)

        allFreezing = pd.concat([toneFreezing, ptFreezing, shockFreezing, pshockFreezing],axis=1)
        
        ## exporting
        freezingOutfile = outpath + '/extRet-freezing-{}.csv'
        freezingOutfile = freezingOutfile.format(ID)
        
        allFreezing.to_csv(freezingOutfile)
        
        ## plot stuff
        vels = pd.DataFrame(anim['Velocity'])

        plt.style.use('seaborn-white')
        plt.figure(figsize=(16,8),facecolor='white',edgecolor='white')

        # Plots main velocity in black
        line1, = plt.plot(vels,color='k',linewidth=0.1,label='ITI')

        # Loops through tones, plots each one in cyan
        i = 1
        while i <= ntones:
            tone = sr.find_tone_vels(anim,i)
            line2, = plt.plot(tone,color='c',linewidth=0.5,label='Tone')
            i += 1
        
        for timebin in FTs:
            plt.plot([timebin[0],timebin[1]],[-0.3,-0.3],color='#ff4f38',linewidth=3)

        plt.ylim(-0.5,35)
        
        sns.despine(left=True, bottom=True, right=True)
        plt.title(ID + " Extinction Retrieval")
        plt.legend(handles=[line1,line2])
        plt.ylabel('Velocity (cm/s)')
        plt.xlabel('Trial time (s)')

        ## define where to save the fig
        fname = outpath + '/extRet-plot-{}'
        fname = fname.format(ID)

        plt.savefig(fname, dpi=300)

        plt.show()
        plt.close()
# Out:
# C:\Users\Sean\Anaconda3\lib\site-packages\pandas\util\_decorators.py:177: FutureWarning: the 'skip_footer' keyword is deprecated, use 'skipfooter' instead
#   return func(*args, **kwargs)
# C:\Users\Sean\Anaconda3\lib\site-packages\pandas\io\excel.py:329: FutureWarning: The `sheetname` keyword is deprecated, use `sheet_name` instead
#   **kwds)
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial     1.xlsx Track-Arena 1-Subject 1 is 051718F1 in Fear Conditioning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial     1.xlsx Track-Arena 2-Subject 1 is 051718F2 in Fear Conditioning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial     1.xlsx Track-Arena 3-Subject 1 is 051718F3 in Fear Conditioning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial     1.xlsx Track-Arena 4-Subject 1 is 052118F1 in Fear Conditioning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial     2.xlsx Track-Arena 1-Subject 1 is 051718F1 in Extinction Learning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial     2.xlsx Track-Arena 2-Subject 1 is 051718F2 in Extinction Learning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial     2.xlsx Track-Arena 3-Subject 1 is 051718F3 in Extinction Learning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial     2.xlsx Track-Arena 4-Subject 1 is 052118F1 in Extinction Learning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial     3.xlsx Track-Arena 1-Subject 1 is 051718F1 in Ext. Retrieval
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial     3.xlsx Track-Arena 2-Subject 1 is 051718F2 in Ext. Retrieval
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial     3.xlsx Track-Arena 3-Subject 1 is 051718F3 in Ext. Retrieval
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial     3.xlsx Track-Arena 4-Subject 1 is 052118F1 in Ext. Retrieval
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial     4.xlsx Track-Arena 1-Subject 1 is 052118F2 in Fear Conditioning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial     4.xlsx Track-Arena 2-Subject 1 is 052118F3 in Fear Conditioning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial     4.xlsx Track-Arena 3-Subject 1 is 052418F1 in Fear Conditioning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial     4.xlsx Track-Arena 4-Subject 1 is 052418F2 in Fear Conditioning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial     5.xlsx Track-Arena 1-Subject 1 is 052118F4 in Fear Conditioning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial     5.xlsx Track-Arena 2-Subject 1 is 052118F5 in Fear Conditioning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial     5.xlsx Track-Arena 3-Subject 1 is 052318F1 in Fear Conditioning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial     5.xlsx Track-Arena 4-Subject 1 is 052318F2 in Fear Conditioning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial     6.xlsx Track-Arena 1-Subject 1 is 052318F3 in Fear Conditioning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial     6.xlsx Track-Arena 2-Subject 1 is 052318F4 in Fear Conditioning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial     6.xlsx Track-Arena 3-Subject 1 is 052418F3 in Fear Conditioning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial     6.xlsx Track-Arena 4-Subject 1 is 052418F4 in Fear Conditioning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial     7.xlsx Track-Arena 1-Subject 1 is 052118F2 in Extinction Learning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial     7.xlsx Track-Arena 2-Subject 1 is 052118F3 in Extinction Learning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial     7.xlsx Track-Arena 3-Subject 1 is 052418F1 in Extinction Learning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial     7.xlsx Track-Arena 4-Subject 1 is 052418F2 in Extinction Learning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial     8.xlsx Track-Arena 1-Subject 1 is 052118F4 in Extinction Learning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial     8.xlsx Track-Arena 2-Subject 1 is 052118F5 in Extinction Learning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial     8.xlsx Track-Arena 3-Subject 1 is 052318F1 in Extinction Learning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial     8.xlsx Track-Arena 4-Subject 1 is 052318F2 in Extinction Learning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial     9.xlsx Track-Arena 1-Subject 1 is 052318F3 in Extinction Learning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial     9.xlsx Track-Arena 2-Subject 1 is 052318F4 in Extinction Learning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial     9.xlsx Track-Arena 3-Subject 1 is 052418F3 in Extinction Learning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial     9.xlsx Track-Arena 4-Subject 1 is 052418F4 in Extinction Learning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    10.xlsx Track-Arena 1-Subject 1 is 052118F2 in Ext. Retrieval
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    10.xlsx Track-Arena 2-Subject 1 is 052118F3 in Ext. Retrieval
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    10.xlsx Track-Arena 3-Subject 1 is 052418F1 in Ext. Retrieval
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    10.xlsx Track-Arena 4-Subject 1 is 052418F2 in Ext. Retrieval
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    11.xlsx Track-Arena 1-Subject 1 is 052118F4 in Ext. Retrieval
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    11.xlsx Track-Arena 2-Subject 1 is 052118F5 in Ext. Retrieval
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    11.xlsx Track-Arena 3-Subject 1 is 052318F1 in Ext. Retrieval
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    11.xlsx Track-Arena 4-Subject 1 is 052318F2 in Ext. Retrieval
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    12.xlsx Track-Arena 1-Subject 1 is 052318F3 in Ext. Retrieval
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    12.xlsx Track-Arena 2-Subject 1 is 052318F4 in Ext. Retrieval
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    12.xlsx Track-Arena 3-Subject 1 is 052418F3 in Ext. Retrieval
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    12.xlsx Track-Arena 4-Subject 1 is 052418F4 in Ext. Retrieval
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    13.xlsx Track-Arena 1-Subject 1 is 053118F1 in Fear Conditioning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    13.xlsx Track-Arena 2-Subject 1 is 053118F2 in Fear Conditioning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    13.xlsx Track-Arena 3-Subject 1 is nan in Fear Conditioning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    13.xlsx Track-Arena 4-Subject 1 is nan in Fear Conditioning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    14.xlsx Track-Arena 1-Subject 1 is 053118F1 in Extinction Learning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    14.xlsx Track-Arena 2-Subject 1 is 053118F2 in Extinction Learning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    14.xlsx Track-Arena 3-Subject 1 is nan in Extinction Learning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    14.xlsx Track-Arena 4-Subject 1 is nan in Extinction Learning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    15.xlsx Track-Arena 1-Subject 1 is 053118F1 in Ext. Retrieval
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    15.xlsx Track-Arena 2-Subject 1 is 053118F2 in Ext. Retrieval
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    15.xlsx Track-Arena 3-Subject 1 is nan in Ext. Retrieval
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    15.xlsx Track-Arena 4-Subject 1 is nan in Ext. Retrieval
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    16.xlsx Track-Arena 1-Subject 1 is 060618F1 in Fear Conditioning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    16.xlsx Track-Arena 2-Subject 1 is 060618F2 in Fear Conditioning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    16.xlsx Track-Arena 3-Subject 1 is nan in Fear Conditioning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    16.xlsx Track-Arena 4-Subject 1 is nan in Fear Conditioning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    17.xlsx Track-Arena 1-Subject 1 is 060618F1 in Extinction Learning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    17.xlsx Track-Arena 2-Subject 1 is 060618F2 in Extinction Learning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    17.xlsx Track-Arena 3-Subject 1 is nan in Extinction Learning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    17.xlsx Track-Arena 4-Subject 1 is nan in Extinction Learning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    18.xlsx Track-Arena 1-Subject 1 is 060618F1 in Ext. Retrieval
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    18.xlsx Track-Arena 2-Subject 1 is 060618F2 in Ext. Retrieval
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    18.xlsx Track-Arena 3-Subject 1 is nan in Ext. Retrieval
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    18.xlsx Track-Arena 4-Subject 1 is nan in Ext. Retrieval
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    19.xlsx Track-Arena 1-Subject 1 is 061318F1 in Fear Conditioning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    19.xlsx Track-Arena 2-Subject 1 is 061318F2 in Fear Conditioning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    19.xlsx Track-Arena 3-Subject 1 is 061418F1 in Fear Conditioning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    19.xlsx Track-Arena 4-Subject 1 is 061418F2 in Fear Conditioning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    20.xlsx Track-Arena 1-Subject 1 is Unknown in Fear Conditioning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    20.xlsx Track-Arena 2-Subject 1 is 061318F4 in Fear Conditioning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    20.xlsx Track-Arena 3-Subject 1 is 061418F3 in Fear Conditioning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    20.xlsx Track-Arena 4-Subject 1 is 061418F4 in Fear Conditioning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    21.xlsx Track-Arena 1-Subject 1 is 061318F1 in Extinction Learning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    21.xlsx Track-Arena 2-Subject 1 is 061318F2 in Extinction Learning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    21.xlsx Track-Arena 3-Subject 1 is 061418F1 in Extinction Learning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    21.xlsx Track-Arena 4-Subject 1 is 061418F2 in Extinction Learning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    22.xlsx Track-Arena 1-Subject 1 is Unknown in Extinction Learning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    22.xlsx Track-Arena 2-Subject 1 is 061318F4 in Extinction Learning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    22.xlsx Track-Arena 3-Subject 1 is 061418F3 in Extinction Learning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    22.xlsx Track-Arena 4-Subject 1 is 061418F4 in Extinction Learning
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    23.xlsx Track-Arena 1-Subject 1 is 061318F1 in Ext. Retrieval
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    23.xlsx Track-Arena 2-Subject 1 is 061318F2 in Ext. Retrieval
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    23.xlsx Track-Arena 3-Subject 1 is 061418F1 in Ext. Retrieval
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    23.xlsx Track-Arena 4-Subject 1 is 061418F2 in Ext. Retrieval
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    24.xlsx Track-Arena 1-Subject 1 is Unknown in Ext. Retrieval
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    24.xlsx Track-Arena 2-Subject 1 is 061318F4 in Ext. Retrieval
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    24.xlsx Track-Arena 3-Subject 1 is 061418F3 in Ext. Retrieval
# C:\Users\Sean\Desktop\ShanskyLab_Projects\TestData\PFC-PAG\AUG03\Raw data-PFC-PAG DREADDs July 2018-Trial    24.xlsx Track-Arena 4-Subject 1 is 061418F4 in Ext. Retrieval
